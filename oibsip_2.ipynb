# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('CarPrice_Assignment.csv')
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.drop('car_ID' , axis =1  , inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
data.corr()['price']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13432\2971354294.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()['price']
# symboling          -0.079978
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginesize          0.874145
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.heatmap(data.corr())
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13432\2889408299.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())

# %%
# We will try to eliminate some columns from the data which are not so correlated to our output column.

# %%
# plt.figure(figsize = (50 , 50))
# sns.pairplot(data)

# %%
# peakrpm , symboling , carheight , stroke , compressing ratio : this columns are very less correlated to our output column so we can drpo them as they dont make any kind of sense for our problem

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.drop(['peakrpm' , 'symboling' , 'carheight',   'stroke' ,  'compressionratio'] ,axis =1 , inplace = True)

# %%
data.sample(5)
# Out:
#                       CarName fueltype aspiration doornumber carbody  \
# 100              nissan nv200      gas        std       four   sedan
# 117             peugeot 604sl      gas      turbo       four   sedan
# 137                  saab 99e      gas      turbo       four   sedan
# 67   buick electra 225 custom   diesel      turbo       four   sedan
# 73      buick century special      gas        std       four   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  curbweight  \
# 100        fwd          front       97.2      173.4      65.2        2302
# 117        rwd          front      108.0      186.7      68.3        3130
# 137        fwd          front       99.1      186.6      66.5        2847
# 67         rwd          front      110.0      190.9      70.3        3515
# 73         rwd          front      120.9      208.1      71.7        3900
#
#     enginetype cylindernumber  enginesize fuelsystem  boreratio  horsepower  \
# ...

# %%
data.shape
# Out:
# (205, 20)

# %%
def clean_carname(x):
    return x.split(" ")[0]

data.CarName.apply(clean_carname).value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: CarName, dtype: int64

# %%
# Some issues are there in carname: toyota : toyouta , nissan : Nissan , maxda : maxda , volkswagen : vokswagen : vw , porsche : porcshce

# %%
def clean_again(x):
    name = x.split(" ")[0]
    if name == 'Nissan':
        return "nissan"
    elif name == 'toyouta':
        return "toyota"
    elif name == "maxda":
        return "mazda"
    elif name == "vokswagen" or name == "vw":
        return "volkswagen"
    elif name == "porcshce":
        return "porsche"
    else:
        return name
    
data.CarName = data.CarName.apply(clean_again)

# %%
plt.figure(figsize = (10 , 10))
sns.barplot(x = data.CarName , y = data.price)
plt.xticks(rotation = 90)
plt.show()

# %%
data.fueltype.value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
data.fueltype.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True , explode = [0 , 0.2])
# Out:
# <AxesSubplot: ylabel='fueltype'>

# %%
sns.displot(x = data.fueltype , y = data.price) # some sort ordinal behaviour but diesel we have very less number of obs so we will use one hot only

# %%
data.aspiration.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True , explode = [0,.2])
# Out:
# <AxesSubplot: ylabel='aspiration'>

# %%
sns.displot(x = data.aspiration , y = data.price)

# %%
data.doornumber.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True , explode = [0,.2])
# Out:
# <AxesSubplot: ylabel='doornumber'>

# %%
sns.displot(x = data.doornumber , y = data.price)

# %%
data.carbody.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True )
# Out:
# <AxesSubplot: ylabel='carbody'>

# %%
sns.barplot(x = data.carbody , y = data.price)
# Out:
# <AxesSubplot: xlabel='carbody', ylabel='price'>

# %%
data.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
# 3         audi      gas        std       four        sedan        fwd
# 4         audi      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  curbweight enginetype  \
# 0          front       88.6      168.8      64.1        2548       dohc
# 1          front       88.6      168.8      64.1        2548       dohc
# 2          front       94.5      171.2      65.5        2823       ohcv
# 3          front       99.8      176.6      66.2        2337        ohc
# 4          front       99.4      176.6      66.4        2824        ohc
#
#   cylindernumber  enginesize fuelsystem  boreratio  horsepower  citympg  \
# ...

# %%
data.drivewheel.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True )
# Out:
# <AxesSubplot: ylabel='drivewheel'>

# %%
sns.barplot(x = data.drivewheel , y = data.price)
# Out:
# <AxesSubplot: xlabel='drivewheel', ylabel='price'>

# %%
data.enginelocation.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True )
# Out:
# <AxesSubplot: ylabel='enginelocation'>

# %%
# very imabalanced column better to drop it
data.drop('enginelocation' , axis = 1 , inplace = True)

# %%
data.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
# 3         audi      gas        std       four        sedan        fwd
# 4         audi      gas        std       four        sedan        4wd
#
#    wheelbase  carlength  carwidth  curbweight enginetype cylindernumber  \
# 0       88.6      168.8      64.1        2548       dohc           four
# 1       88.6      168.8      64.1        2548       dohc           four
# 2       94.5      171.2      65.5        2823       ohcv            six
# 3       99.8      176.6      66.2        2337        ohc           four
# 4       99.4      176.6      66.4        2824        ohc           five
#
#    enginesize fuelsystem  boreratio  horsepower  citympg  highwaympg    price
# ...

# %%
data.enginetype.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True )
# Out:
# <AxesSubplot: ylabel='enginetype'>

# %%
sns.barplot(x = data.enginetype , y = data.price)
# Out:
# <AxesSubplot: xlabel='enginetype', ylabel='price'>

# %%
data.cylindernumber.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True )
# Out:
# <AxesSubplot: ylabel='cylindernumber'>

# %%
sns.barplot(x = data.cylindernumber , y = data.price)
# Out:
# <AxesSubplot: xlabel='cylindernumber', ylabel='price'>

# %%
sns.barplot(x = data.fuelsystem , y = data.price)
# Out:
# <AxesSubplot: xlabel='fuelsystem', ylabel='price'>

# %%
data.fuelsystem.value_counts().plot(kind = 'pie' , autopct = "%0.1f" , shadow = True )
# Out:
# <AxesSubplot: ylabel='fuelsystem'>

# %%
# For numerical columns we have just checkef with the correlation and there distribution
# we can do many things like making the distributions normal or checking for the outliers etc but let's build a model without touching them if needed then we will do necessary steps

# %%
data.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
# 3         audi      gas        std       four        sedan        fwd
# 4         audi      gas        std       four        sedan        4wd
#
#    wheelbase  carlength  carwidth  curbweight enginetype cylindernumber  \
# 0       88.6      168.8      64.1        2548       dohc           four
# 1       88.6      168.8      64.1        2548       dohc           four
# 2       94.5      171.2      65.5        2823       ohcv            six
# 3       99.8      176.6      66.2        2337        ohc           four
# 4       99.4      176.6      66.4        2824        ohc           five
#
#    enginesize fuelsystem  boreratio  horsepower  citympg  highwaympg    price
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor , AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score

# %%
x = data.drop('price' , axis = 1)
y = data.price

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x,y, test_size = 0.2 ,random_state = 42)

# %%
xtrain.shape , xtest.shape
# Out:
# ((164, 18), (41, 18))

# %%
xtrain
# Out:
#      CarName fueltype aspiration doornumber    carbody drivewheel  wheelbase  \
# 66     mazda   diesel        std       four      sedan        rwd      104.9
# 111  peugeot      gas        std       four      sedan        rwd      107.9
# 153   toyota      gas        std       four      wagon        fwd       95.7
# 96    nissan      gas        std       four      sedan        fwd       94.5
# 38     honda      gas        std        two  hatchback        fwd       96.5
# ..       ...      ...        ...        ...        ...        ...        ...
# 106   nissan      gas        std        two  hatchback        rwd       99.2
# 14       bmw      gas        std       four      sedan        rwd      103.5
# 92    nissan      gas        std       four      sedan        fwd       94.5
# 179   toyota      gas        std        two  hatchback        rwd      102.9
# 102   nissan      gas        std       four      wagon        fwd      100.4
#
# ...

# %%
one = OneHotEncoder()
one.fit(x[['CarName' , 'fueltype' , 'aspiration' , 'doornumber' , 'carbody' , 'drivewheel' , 'enginetype' , 'cylindernumber', 'fuelsystem']])
categories = one.categories_
categories
# Out:
# [array(['alfa-romero', 'audi', 'bmw', 'buick', 'chevrolet', 'dodge',
#         'honda', 'isuzu', 'jaguar', 'mazda', 'mercury', 'mitsubishi',
#         'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#         'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object),
#  array(['diesel', 'gas'], dtype=object),
#  array(['std', 'turbo'], dtype=object),
#  array(['four', 'two'], dtype=object),
#  array(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'],
#        dtype=object),
#  array(['4wd', 'fwd', 'rwd'], dtype=object),
#  array(['dohc', 'dohcv', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor'], dtype=object),
#  array(['eight', 'five', 'four', 'six', 'three', 'twelve', 'two'],
#        dtype=object),
#  array(['1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'],
#        dtype=object)]

# %%
col1 = ColumnTransformer(transformers = [('onehotencoder' , OneHotEncoder(categories = categories , drop = 'first') , 
                                        [0,1,2,3,4,5,10,11,13])],
                        remainder = 'passthrough')

# %%
xtrain = col1.fit_transform(xtrain).todense()
xtest = col1.transform(xtest).todense()

# %%
xtrain.shape
# Out:
# (164, 58)

# %%
col2 = ColumnTransformer(transformers = [('scaling' , StandardScaler() , slice(0,59))] , remainder = "passthrough")

# %%
xtrain = col2.fit_transform(np.array(xtrain))
xtest = col2.transform(np.array(xtest))

# %%
rf = RandomForestRegressor()
rf.fit(xtrain , ytrain)
ypred1 = rf.predict(xtest)
r2_score(ytest , ypred1)
# Out:
# 0.957688188591756

# %%
lr = LinearRegression()
lr.fit(xtrain , ytrain)
ypred2 = lr.predict(xtest)
r2_score(ytest , ypred2)
# Out:
# -5.101190466657873e+23

# %%
gd = GradientBoostingRegressor()
gd.fit(xtrain , ytrain)
ypred3 = gd.predict(xtest)
r2_score(ytest, ypred3)
# Out:
# 0.9217001894929453

# %%
ad = AdaBoostRegressor()
ad.fit(xtrain , ytrain)
ypred4 = ad.predict(xtest)
r2_score(ytest , ypred4)
# Out:
# 0.9039411259491635

# %%
sv = SVR()
sv.fit(xtrain , ytrain)
ypred5 = sv.predict(xtest)
r2_score(ytest , ypred5)
# Out:
# -0.100515896378357

# %%
dt = DecisionTreeRegressor()
dt.fit(xtrain , ytrain)
ypred6 = dt.predict(xtest)
r2_score(ytest , ypred6)
# Out:
# 0.8838508954008171

# %%
# Random Forest regressor is giving the best accuracy although we can do hyperparamter tuning using grid search cv but again data is to too less to capture the relationships.
